# %% [markdown]
# # Curso de Introdução a Programação com Python

# %% [markdown]
# # STRINGS

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %% [markdown]
# Concatenação de strings

# %%
print('Ma xsuel ' + 'Marcos')
# Out:
# Ma xsuel Marcos

# %%
a = ' homem '
b = ' safado '
c = a+b
print(c)
# Out:
#  homem  safado

# %% [markdown]
#  Manipulação de strings

# %%
len(c)
# Out:
# 16

# %%
c.capitalize()
# Out:
# 'Homemsafado'

# %%
c.count('amor')
# Out:
# 0

# %%
c.title()
# Out:
# 'Programação Python'

# %%
c.split()
# Out:
# ['homem', 'safado']

# %%
c.strip()
# Out:
# 'homem  safado'

# %% [markdown]
# Fatiamento de strings

# %%
s = "Python"

# %%
s[2:5]
# Out:
# 'tho'

# %%
s[2:]
# Out:
# 'thon'

# %%
s[:4]
# Out:
# 'Pyth'

# %% [markdown]
#  ## Exercícios: strings
#
#  1 – Considere a string A = "Um elefante incomoda muita gente". Que fatia corresponde a "elefante
# incomoda"
#
#  2 - Escreva um programa que solicite uma frase ao usuário e escreva a frase toda em maiúscula e
# sem espaços em branco ?

# %%
A = "Um elefante incomoda muita gente"

# %%
A[3:20]
# Out:
# 'elefante incomoda'

# %%
nome = input('Como é o nome da sua mãe e do seu pai? ')
# Out:
# Como é o nome da sua mãe e do seu pai?      ivonete fernande e marcos

# %%
n = nome.upper()

# %%
n
# Out:
# '    IVONETE FERNANDE E MARCOS '

# %%
n.strip()
# Out:
# 'IVONETE FERNANDE E MARCOS'
